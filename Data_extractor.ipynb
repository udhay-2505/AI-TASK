# %%
# !pip install langchain requests selenium beautifulsoup4

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB 640.0 kB/s eta 0:00:04
#    ---------------------------------------- 0.0/2.5 MB 640.0 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.3/2.5 MB 1.7 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/2.5 MB 2.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.5 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 2.0/2.5 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 8.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 32.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/413.0 kB ? eta -:--:--
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
from langchain.document_loaders import WebBaseLoader
url = "https://brainlox.com/courses/category/technical"
loader = WebBaseLoader(url)
documents = loader.load()

for doc in documents:
    print(doc.page_content)
# Out:
# Brainlox: Learn technical courses.Courses TechnicalAcademicLanguageMusicLifestyleBook a Free Demo NowSign InFAQContact UsHomeCoursesCoursesWe found great courses available for you$30per sessionLEARN SCRATCH PROGRAMING
# Scratch Course is the foundation of coding and is a building block of a coding journey. If you want 16 LessonsView Details$30per sessionLEARN CLOUD COMPUTING BASICS-AWS
# In this course we are going to cover the basics and the most important services on AWS,
# At the end  20 LessonsView Details$30per sessionLEARN MOBILE DEVELOPMENT
# Mobile application development is the process of creating software applications that run on a mobil 24 LessonsView Details$30per sessionLEARN CORE JAVA PROGRAMMING ONLINE
# Java is a very popular high-level, class-based, object-oriented programming language that is design 41 LessonsView Details$30per sessionLEARN ROBOTICS
# ...

# %%
# !pip install unstructured

# %%
from langchain.document_loaders import SeleniumURLLoader

urls = ["https://brainlox.com/courses/category/technical"]
loader = SeleniumURLLoader(urls=urls)
documents = loader.load()

for doc in documents:
    print(doc.page_content[:500])  # Print first 500 characters
# Out:
# Courses
#
# Technical
#
# Academic
#
# Language
#
# Music
#
# Lifestyle
#
# Book a Free Demo Now
#
# Sign In
#
# FAQ
#
# Contact Us
#
# Home
#
# Courses
#
# Courses
#
# We found great courses available for you
#
# $30 per session
#
# LEARN SCRATCH PROGRAMING
#
# Scratch Course is the foundation of coding and is a building block of a coding journey. If you want
#
# 16 Lessons
#
# View Details
#
# $30 per session
#
# LEARN CLOUD COMPUTING BASICS-AWS
#
# In this course we are going to cover the basics and the most important services on AWS, At the end
#
# 20 Less

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=1000000, chunk_overlap=0)
chunks = splitter.split_documents(documents)

for chunk in chunks:
    print(chunk.page_content)
# Out:
# Courses
#
# Technical
#
# Academic
#
# Language
#
# Music
#
# Lifestyle
#
# Book a Free Demo Now
#
# Sign In
#
# FAQ
#
# Contact Us
#
# Home
#
# Courses
#
# Courses
#
# We found great courses available for you
#
# $30 per session
#
# LEARN SCRATCH PROGRAMING
#
# Scratch Course is the foundation of coding and is a building block of a coding journey. If you want
#
# 16 Lessons
#
# View Details
#
# $30 per session
#
# LEARN CLOUD COMPUTING BASICS-AWS
#
# In this course we are going to cover the basics and the most important services on AWS, At the end
#
# 20 Lessons
#
# View Details
#
# $30 per session
#
# LEARN MOBILE DEVELOPMENT
#
# Mobile application development is the process of creating software applications that run on a mobil
#
# 24 Lessons
#
# View Details
#
# $30 per session
#
# LEARN CORE JAVA PROGRAMMING ONLINE
#
# Java is a very popular high-level, class-based, object-oriented programming language that is design
#
# 41 Lessons
#
# View Details
#
# $30 per session
#
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings
import numpy as np

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")


vectorstore = FAISS.from_documents(chunks, embeddings)

# %%
import os
from langchain_community.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS


url = "https://brainlox.com/courses/category/technical"
loader = WebBaseLoader(url)
documents = loader.load()


splitter = RecursiveCharacterTextSplitter(chunk_size=1000000, chunk_overlap=0)
chunks = splitter.split_documents(documents)


embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")


vectorstore = FAISS.from_documents(chunks, embeddings)

vectorstore.save_local("faiss_brainlox_courses")

print(" embeddings generated and stored in FAISS successfully!")
# Out:
#  embeddings generated and stored in FAISS successfully!

# %%
vectorstore = FAISS.load_local("faiss_brainlox_courses", embeddings, allow_dangerous_deserialization=True)

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

# Initialize Hugging Face embeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# Create FAISS vector store
vectorstore = FAISS.from_documents(chunks, embeddings)

# Save the FAISS index locally
vectorstore.save_local("faiss_brainlox_courses")
print("✅ FAISS index saved successfully!")
# Out:
# ✅ FAISS index saved successfully!

# %%
# Load FAISS index with safe deserialization
vectorstore = FAISS.load_local(
    "faiss_brainlox_courses",
    embeddings,
    allow_dangerous_deserialization=True  # ✅ Ensures FAISS loads properly
)

# Perform similarity search
query = "What are  the available courses"
results = vectorstore.similarity_search(query, k=3)

# Print search results
for i, doc in enumerate(results):
    print(f"\n🔹 Result {i+1}:")
    print(doc.page_content)
# Out:
# 🔹 Result 1:
# Brainlox: Learn technical courses.Courses TechnicalAcademicLanguageMusicLifestyleBook a Free Demo NowSign InFAQContact UsHomeCoursesCoursesWe found great courses available for you$30per sessionLEARN SCRATCH PROGRAMING
# Scratch Course is the foundation of coding and is a building block of a coding journey. If you want 16 LessonsView Details$30per sessionLEARN CLOUD COMPUTING BASICS-AWS
# In this course we are going to cover the basics and the most important services on AWS,
# At the end  20 LessonsView Details$30per sessionLEARN MOBILE DEVELOPMENT
# Mobile application development is the process of creating software applications that run on a mobil 24 LessonsView Details$30per sessionLEARN CORE JAVA PROGRAMMING ONLINE
# Java is a very popular high-level, class-based, object-oriented programming language that is design 41 LessonsView Details$30per sessionLEARN ROBOTICS
# ...

# %%
# import os
# from langchain.vectorstores import FAISS
# from langchain.embeddings import HuggingFaceEmbeddings
# from langchain.chat_models import ChatOpenAI
# from langchain.chains import RetrievalQA

# # 🔹 Step 1: Load the FAISS index (with safe deserialization)
# embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# vectorstore = FAISS.load_local(
#     "faiss_brainlox_courses",
#     embeddings,
#     allow_dangerous_deserialization=True
# )

# # 🔹 Step 2: Initialize Chat Model (Replace with Llama2 if needed)
# os.environ["OPENAI_API_KEY"] = "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"  # Replace if using OpenAI
# chat_model = ChatOpenAI(model_name="gpt-3.5-turbo")  # You can use Hugging Face models too

# # 🔹 Step 3: Create the Retrieval-based Chatbot
# qa_chain = RetrievalQA.from_chain_type(
#     llm=chat_model,
#     retriever=vectorstore.as_retriever(),
#     return_source_documents=True
# )

# # 🔹 Step 4: Run the Chatbot
# while True:
#     query = input("\nAsk a question (or type 'exit' to stop): ")
#     if query.lower() == "exit":
#         break
    
#     response = qa_chain({"query": query})
#     print("\n🤖 Chatbot Answer:", response["result"])

# %%
from huggingface_hub import login

login(token="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")

# %%
# !pip install google-generativeai
# Out:
# ...
#   Using cached google_generativeai-0.8.4-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached grpcio_status-1.70.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Using cached google_generativeai-0.8.4-py3-none-any.whl (175 kB)
# Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
# ...
#    ---------------------------------------- 0.0/160.1 kB ? eta -:--:--
# ...

# %%
import google.generativeai as genai

def setup_gemini(api_key):
    """Initialize the Gemini API with your API key."""
    genai.configure(api_key=api_key)
    return genai.GenerativeModel("gemini-pro")

def chat_with_gemini(model, user_input):
    """Send user input to Gemini and return the response."""
    response = model.generate_content(user_input)
    return response.text

# Replace 'YOUR_GEMINI_API_KEY' with your actual API key
gemini_api_key = "AIzaSyCHHPeGGK6---Tj7CpVvbCGbUlA0GD_XKo"
model = setup_gemini(gemini_api_key)

# Example conversation
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting chatbot...")
        break
    response = chat_with_gemini(model, user_input)
    print("Gemini:", response)
# Out:
# You:  python course
# Gemini: **Python Course Outline**
#
# **Module 1: Python Basics**
#
# * Introduction to Python
# * Data types and variables
# * Operators and expressions
# * Control flow: if-else, loops
# * Functions and modules
# * Exception handling
#
# **Module 2: Object-Oriented Programming (OOP)**
#
# * Classes and objects
# * Inheritance and polymorphism
# * Class methods and static methods
# * Encapsulation and data hiding
#
# **Module 3: Data Structures and Algorithms**
#
# * Lists, tuples, and sets
# * Dictionaries
# * Stacks and queues
# * Sorting and searching algorithms
# * Data structures analysis
#
# **Module 4: File Handling and Input/Output**
#
# * Reading and writing files
# * File formats and encodings
# * Input and output streams
# * Command-line arguments
#
# **Module 5: Database Connectivity**
#
# * Introduction to databases (SQL)
# * Connecting to databases using Python
# * Executing queries and retrieving results
# * Data manipulation language (DML)
#
# ...
